# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import requests

# %%
df = pd.read_excel("C:\\Users\\thepr\\Downloads\\kpxx.xlsx")
print(df)
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# ...

# %%
df.head(5)
# Out:
#    SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0        1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 1        2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 2        3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 3        4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4        5          SO43663 2023-06-01 2023-06-12    29489.272  North
#
#    MarketingSpend SalesTeam  Unnamed: 8  Unnamed: 9 Unnamed: 10  Unnamed: 11
# 0            4000    Team A         NaN         NaN         NaN          NaN
# 1            8000    Team B         NaN         NaN         NaN          NaN
# 2            5000    Team B         NaN         NaN         NaN          NaN
# 3           10000    Team A         NaN         NaN         NaN          NaN
# 4            4500    Team A         NaN         NaN         NaN          NaN

# %%
df.tail(5)
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# 12       13          SO43671 2023-07-05 2023-07-16    34221.456  North
# 13       14          SO43672 2023-07-06 2023-07-17   170534.849   East
# 14       15          SO43673 2023-07-07 2023-07-18    41875.219  South
# 15       16          SO43674 2023-07-08 2023-07-19    29598.924   West
#
#     MarketingSpend SalesTeam  Unnamed: 8  Unnamed: 9      Unnamed: 10  \
# 11           13000    Team A         NaN         NaN  sales per month
# 12            5200    Team A         NaN         NaN              may
# 13            9500    Team B         NaN         NaN             june
# 14            6500    Team B         NaN         NaN             july
# 15           14000    Team A         NaN         NaN              NaN
#
#     Unnamed: 11
# 11          NaN
# 12   238237.344
# 13   254473.505
# 14   543263.066
# 15          NaN

# %%
df.describe()
# Out:
#          SalesID            OrderDate              DueDate    SalesAmount  \
# count  16.000000                   16                   16      16.000000
# mean    8.500000  2023-06-10 18:00:00  2023-06-21 18:00:00   64748.369687
# min     1.000000  2023-05-01 00:00:00  2023-05-12 00:00:00   23153.233000
# 25%     4.750000  2023-05-25 00:00:00  2023-06-05 00:00:00   31163.552750
# 50%     8.500000  2023-06-17 12:00:00  2023-06-28 12:00:00   35543.421500
# 75%    12.250000  2023-07-04 06:00:00  2023-07-15 06:00:00   67842.362250
# max    16.000000  2023-07-08 00:00:00  2023-07-19 00:00:00  170534.849000
# std     4.760952                  NaN                  NaN   56539.255153
#
#        MarketingSpend  Unnamed: 8  Unnamed: 9   Unnamed: 11
# count        16.00000         0.0         0.0  5.000000e+00
# mean       7856.25000         NaN         NaN  4.273392e+05
# min        4000.00000         NaN         NaN  6.474837e+04
# 25%        5150.00000         NaN         NaN  2.382373e+05
# ...

# %%
df.count()
# Out:
# SalesID             16
# SalesOrderNumber    16
# OrderDate           16
# DueDate             16
# SalesAmount         16
# Region              16
# MarketingSpend      16
# SalesTeam           16
# Unnamed: 8           0
# Unnamed: 9           0
# Unnamed: 10          6
# Unnamed: 11          5
# dtype: int64

# %%
print(df.shape)
# Out:
# (16, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SalesID           16 non-null     int64
#  1   SalesOrderNumber  16 non-null     object
#  2   OrderDate         16 non-null     datetime64[ns]
#  3   DueDate           16 non-null     datetime64[ns]
#  4   SalesAmount       16 non-null     float64
#  5   Region            16 non-null     object
#  6   MarketingSpend    16 non-null     int64
#  7   SalesTeam         16 non-null     object
#  8   Unnamed: 8        0 non-null      float64
#  9   Unnamed: 9        0 non-null      float64
#  10  Unnamed: 10       6 non-null      object
#  11  Unnamed: 11       5 non-null      float64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(4)
# memory usage: 1.6+ KB

# %%
print(df.columns)
# Out:
# Index(['SalesID', 'SalesOrderNumber', 'OrderDate', 'DueDate', 'SalesAmount',
#        'Region', 'MarketingSpend', 'SalesTeam', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
df.pivot_table(values="SalesAmount", index="Region")
# Out:
#          SalesAmount
# Region
# East    158907.69050
# North    29579.54675
# South    39473.43925
# West     31032.80225

# %%
import matplotlib.pyplot as plt

# %%
plt.figure();
df.plot();

# %%
df.plot(x="Region", y="SalesAmount", kind="bar")
plt.show()

# %%
df.plot(x="Region", y="SalesAmount", kind="line")
plt.show()

# %%
df['SalesTeam'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SalesTeam'>

# %%
df.isnull()
# Out:
#     SalesID  SalesOrderNumber  OrderDate  DueDate  SalesAmount  Region  \
# 0     False             False      False    False        False   False
# 1     False             False      False    False        False   False
# 2     False             False      False    False        False   False
# 3     False             False      False    False        False   False
# 4     False             False      False    False        False   False
# 5     False             False      False    False        False   False
# 6     False             False      False    False        False   False
# 7     False             False      False    False        False   False
# 8     False             False      False    False        False   False
# 9     False             False      False    False        False   False
# 10    False             False      False    False        False   False
# 11    False             False      False    False        False   False
# ...

# %%
print(df.columns)
# Out:
# Index(['SalesID', 'SalesOrderNumber', 'OrderDate', 'DueDate', 'SalesAmount',
#        'Region', 'MarketingSpend', 'SalesTeam', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
s_data = df[['SalesAmount' ,'Region']]
print(s_data)
# Out:
#     SalesAmount Region
# 0     23153.233  North
# 1    145743.792   East
# 2     36865.387  South
# 3     32474.932   West
# 4     29489.272  North
# 5    155098.272   East
# 6     38587.532  South
# 7     31298.429   West
# 8     31454.226  North
# 9    164253.849   East
# 10    40565.619  South
# 11    30758.924   West
# 12    34221.456  North
# 13   170534.849   East
# 14    41875.219  South
# 15    29598.924   West

# %%
f_data = df[df['SalesAmount']>10000]
f_data
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# ...

# %%
f_data = df[df['MarketingSpend']<5000]
f_data
# Out:
#    SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0        1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 4        5          SO43663 2023-06-01 2023-06-12    29489.272  North
#
#    MarketingSpend SalesTeam  Unnamed: 8  Unnamed: 9 Unnamed: 10  Unnamed: 11
# 0            4000    Team A         NaN         NaN         NaN          NaN
# 4            4500    Team A         NaN         NaN         NaN          NaN

# %%
f_data = df[(df['MarketingSpend']>8000) & (df['SalesAmount']>20000)]
f_data
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# 13       14          SO43672 2023-07-06 2023-07-17   170534.849   East
# 15       16          SO43674 2023-07-08 2023-07-19    29598.924   West
#
#     MarketingSpend SalesTeam  Unnamed: 8  Unnamed: 9      Unnamed: 10  \
# 3            10000    Team A         NaN         NaN              NaN
# 5             8500    Team B         NaN         NaN              NaN
# 7            12000    Team A         NaN         NaN              NaN
# 9             9000    Team B         NaN         NaN      total sales
# ...

# %%
f_data = df[(df['Region'] == 'West') | (df['Region'] == 'East')]
f_data
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# 13       14          SO43672 2023-07-06 2023-07-17   170534.849   East
# 15       16          SO43674 2023-07-08 2023-07-19    29598.924   West
#
#     MarketingSpend SalesTeam  Unnamed: 8  Unnamed: 9      Unnamed: 10  \
# 1             8000    Team B         NaN         NaN              NaN
# 3            10000    Team A         NaN         NaN              NaN
# 5             8500    Team B         NaN         NaN              NaN
# ...

# %%
f_data = df[df['SalesTeam'] =='Team A']
f_data
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# 12       13          SO43671 2023-07-05 2023-07-16    34221.456  North
# 15       16          SO43674 2023-07-08 2023-07-19    29598.924   West
#
#     MarketingSpend SalesTeam  Unnamed: 8  Unnamed: 9      Unnamed: 10  \
# 0             4000    Team A         NaN         NaN              NaN
# 3            10000    Team A         NaN         NaN              NaN
# 4             4500    Team A         NaN         NaN              NaN
# ...

# %%
df.iloc[0:5]
# Out:
#    SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0        1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 1        2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 2        3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 3        4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4        5          SO43663 2023-06-01 2023-06-12    29489.272  North
#
#    MarketingSpend SalesTeam  Unnamed: 8  Unnamed: 9 Unnamed: 10  Unnamed: 11
# 0            4000    Team A         NaN         NaN         NaN          NaN
# 1            8000    Team B         NaN         NaN         NaN          NaN
# 2            5000    Team B         NaN         NaN         NaN          NaN
# 3           10000    Team A         NaN         NaN         NaN          NaN
# 4            4500    Team A         NaN         NaN         NaN          NaN

# %%
g_data = df.dropna()
g_data
# Out:
# Empty DataFrame
# Columns: [SalesID, SalesOrderNumber, OrderDate, DueDate, SalesAmount, Region, MarketingSpend, SalesTeam, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11]
# Index: []

# %%
f_data = df[df['SalesID']>12]
f_data
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 12       13          SO43671 2023-07-05 2023-07-16    34221.456  North
# 13       14          SO43672 2023-07-06 2023-07-17   170534.849   East
# 14       15          SO43673 2023-07-07 2023-07-18    41875.219  South
# 15       16          SO43674 2023-07-08 2023-07-19    29598.924   West
#
#     MarketingSpend SalesTeam  Unnamed: 8  Unnamed: 9 Unnamed: 10  Unnamed: 11
# 12            5200    Team A         NaN         NaN         may   238237.344
# 13            9500    Team B         NaN         NaN        june   254473.505
# 14            6500    Team B         NaN         NaN        july   543263.066
# 15           14000    Team A         NaN         NaN         NaN          NaN

# %%
g_data = df.drop(['Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis=1)
g_data
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# ...

# %%
g_data.to_excel('new_kpxx.xlsx' , index=False)
print(g_data)
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# ...

# %%
df_sorted = g_data.sort_values(by='SalesAmount')
df_sorted
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 15       16          SO43674 2023-07-08 2023-07-19    29598.924   West
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 12       13          SO43671 2023-07-05 2023-07-16    34221.456  North
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 14       15          SO43673 2023-07-07 2023-07-18    41875.219  South
# ...

# %%
df_sorted = g_data.sort_values(by='SalesAmount' , ascending=False)
df_sorted
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 13       14          SO43672 2023-07-06 2023-07-17   170534.849   East
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 14       15          SO43673 2023-07-07 2023-07-18    41875.219  South
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 12       13          SO43671 2023-07-05 2023-07-16    34221.456  North
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# ...

# %%
df_sorted = g_data.sort_values(by='OrderDate')
df_sorted
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# ...

# %%
df_sorted = g_data.sort_values(by='MarketingSpend')
df_sorted
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 12       13          SO43671 2023-07-05 2023-07-16    34221.456  North
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 14       15          SO43673 2023-07-07 2023-07-18    41875.219  South
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 13       14          SO43672 2023-07-06 2023-07-17   170534.849   East
# ...

# %%
df_sorted = g_data.sort_values(by='MarketingSpend' , ascending=False)
df_sorted
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 15       16          SO43674 2023-07-08 2023-07-19    29598.924   West
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 13       14          SO43672 2023-07-06 2023-07-17   170534.849   East
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 14       15          SO43673 2023-07-07 2023-07-18    41875.219  South
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 12       13          SO43671 2023-07-05 2023-07-16    34221.456  North
# ...

# %%
df_sorted = g_data.sort_values(by=['OrderDate','MarketingSpend'],ascending=[True,False])
df_sorted
# Out:
#     SalesID SalesOrderNumber  OrderDate    DueDate  SalesAmount Region  \
# 0         1          SO43659 2023-05-01 2023-05-12    23153.233  North
# 1         2          SO43660 2023-05-02 2023-05-13   145743.792   East
# 2         3          SO43661 2023-05-03 2023-05-14    36865.387  South
# 3         4          SO43662 2023-05-04 2023-05-15    32474.932   West
# 4         5          SO43663 2023-06-01 2023-06-12    29489.272  North
# 5         6          SO43664 2023-06-02 2023-06-13   155098.272   East
# 6         7          SO43665 2023-06-03 2023-06-14    38587.532  South
# 7         8          SO43666 2023-06-04 2023-06-15    31298.429   West
# 8         9          SO43667 2023-07-01 2023-07-12    31454.226  North
# 9        10          SO43668 2023-07-02 2023-07-13   164253.849   East
# 10       11          SO43669 2023-07-03 2023-07-14    40565.619  South
# 11       12          SO43670 2023-07-04 2023-07-15    30758.924   West
# ...

# %%
df_sorted['SalesAmount'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df_sorted.plot(kind='scatter',x='MarketingSpend',y='SalesAmount')
plt.show()
